# %% [markdown]
# # World Model

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
import joblib
import os

# %% [markdown]
# ## Load Dataset

# %%
def load_data(filepath="../dataset/dataset_limited_2.txt"):
    """Loads the dataset using pandas."""
    try:
        df = pd.read_csv(filepath)
        print(f"Dataset loaded successfully. Shape: {df.shape}")
        df = df.dropna()
        print(f"Shape after dropping NaNs: {df.shape}")
        return df
    except FileNotFoundError:
        print(f"Error: Dataset file not found at {filepath}")
        return None
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None

# %%
# 1. Load the dataset
dataframe = load_data()
# Out:
# Dataset loaded successfully. Shape: (1818, 14)
# Shape after dropping NaNs: (1818, 14)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1818 entries, 0 to 1817
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   distance_red_init     1818 non-null   float64
#  1   angle_red_init        1818 non-null   float64
#  2   distance_green_init   1818 non-null   float64
#  3   angle_green_init      1818 non-null   float64
#  4   distance_blue_init    1818 non-null   float64
#  5   angle_blue_init       1818 non-null   float64
#  6   rSpeed                1818 non-null   int64
#  7   lSpeed                1818 non-null   int64
#  8   distance_red_final    1818 non-null   float64
#  9   angle_red_final       1818 non-null   float64
#  10  distance_green_final  1818 non-null   float64
#  11  angle_green_final     1818 non-null   float64
#  12  distance_blue_final   1818 non-null   float64
#  13  angle_blue_final      1818 non-null   float64
# dtypes: float64(12), int64(2)
# memory usage: 199.0 KB

# %% [markdown]
# ## Preprocess Dataset

# %%
def prepare_data(df):
    """Separates features (X) and target variables (Y)."""
    # Input Features: initial state (6) + action (2) = 8 features
    X = df.iloc[:, :8].values
    # Target Variables: final state (6) = 6 features
    Y = df.iloc[:, 8:].values
    print(f"Features (X) shape: {X.shape}")
    print(f"Targets (Y) shape: {Y.shape}")
    return X, Y

# %%
def split_data(X, Y, test_size=0.2, random_state=42):
    """Splits data into training and testing sets."""
    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, test_size=test_size, random_state=random_state
    )
    print(f"Training set size: {X_train.shape[0]} samples")
    print(f"Testing set size: {X_test.shape[0]} samples")
    return X_train, X_test, Y_train, Y_test

# %%
# 2. Prepare Data
X, Y = prepare_data(dataframe)
# Out:
# Features (X) shape: (1818, 8)
# Targets (Y) shape: (1818, 6)

# %%
def scale_features(X_train, X_test):
    """Scales input features using StandardScaler."""
    
    scaler = StandardScaler()
    
    # Fit scaler ONLY on training data
    X_train_scaled = scaler.fit_transform(X_train)
    
    # Transform both train and test data
    X_test_scaled = scaler.transform(X_test)
    
    print("Features scaled.")
    
    return X_train_scaled, X_test_scaled, scaler # Return scaler to save it

# %%
# 3. Split Data
X_train, X_test, Y_train, Y_test = split_data(X, Y)

# 4. Scale Features (Important!)
X_train_scaled, X_test_scaled, scaler = scale_features(X_train, X_test)
# Out:
# Training set size: 1454 samples
# Testing set size: 364 samples
# Features scaled.

# %% [markdown]
# ## Train model

# %%
# from tqdm import tqdm
import time
from sklearn.model_selection import GridSearchCV

def train_model_with_gridsearch(X_train, Y_train):
    """Trains a RandomForestRegressor using GridSearchCV for hyperparameter tuning."""
    print("\n--- Starting GridSearchCV for RandomForestRegressor ---")

    # Define the parameter grid to search
    # Start with a smaller grid, then expand if needed and time permits
    param_grid = {
        'n_estimators': [100, 200, 300, 500, 1000, 2000],            # Number of trees
        'max_depth': [5, 10, 20, 30, None],           # Max depth of trees (None means no limit initially)
        'min_samples_split': [2, 5, 10, 20],         # Min samples to split a node
        'min_samples_leaf': [1, 3, 5, 10],          # Min samples in a leaf node
        'max_features': ['sqrt', 'log2'],       # Number of features to consider for split
        'oob_score': [True] # Can include if you want OOB score for the final best model
    }

    # Initialize the base model
    rf = RandomForestRegressor(random_state=42, n_jobs=-1) # Use n_jobs in base for fitting final model too

    # Initialize GridSearchCV
    # Scoring: Use negative MAE because GridSearchCV maximizes score. Lower MAE is better.
    # cv=5: 5-fold cross-validation
    # verbose=2: Print progress updates
    # n_jobs=-1: Use all available CPU cores for the search
    grid_search = GridSearchCV(estimator=rf,
                               param_grid=param_grid,
                               cv=5,
                               scoring='neg_mean_absolute_error', # Or 'neg_mean_squared_error'
                               n_jobs=-1,
                               verbose=3) # Increase verbosity to see progress

    print(f"Searching grid: {param_grid}")
    start_time = time.time()

    # Fit GridSearchCV to the data
    grid_search.fit(X_train, Y_train)

    end_time = time.time()
    print(f"GridSearchCV finished in {end_time - start_time:.2f} seconds.")

    # Print the best parameters found
    print("\nBest parameters found by GridSearchCV:")
    print(grid_search.best_params_)

    # Print the best score (negative MAE or MSE)
    print(f"\nBest cross-validation score (Negative MAE): {grid_search.best_score_:.4f}")
    print(f"Corresponds to MAE: {-grid_search.best_score_:.4f}")


    # The best model found by GridSearchCV is stored in best_estimator_
    best_model = grid_search.best_estimator_
    print("\nBest model training complete.")

    # You can optionally check OOB score if it was calculated
    # hasattr checks if the attribute exists before accessing
    if hasattr(best_model, 'oob_score_') and best_model.oob_score_:
        print(f"Best Model OOB score: {best_model.oob_score_:.4f}")

    return best_model

# %%
# 5. Train Model using GridSearchCV (using scaled data)
if X_train_scaled is not None:
    world_model = train_model_with_gridsearch(X_train_scaled, Y_train)
else:
    print("Skipping model training due to data scaling issues.")
    exit()
# Out:
# --- Starting GridSearchCV for RandomForestRegressor ---
# Searching grid: {'n_estimators': [100, 200, 300, 500, 1000, 2000], 'max_depth': [5, 10, 20, 30, None], 'min_samples_split': [2, 5, 10, 20], 'min_samples_leaf': [1, 3, 5, 10], 'max_features': ['sqrt', 'log2'], 'oob_score': [True]}
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, oob_score=True;, score=-51.860 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.332 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, oob_score=True;, score=-51.303 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, oob_score=True;, score=-53.095 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, oob_score=True;, score=-51.044 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.658 total time=   0.5s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.106 total time=   0.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, oob_score=True;, score=-50.807 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.289 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, oob_score=True;, score=-51.131 total time=   0.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.288 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, oob_score=True;, score=-50.708 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, oob_score=True;, score=-51.065 total time=   1.1s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.479 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.019 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.234 total time=   1.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, oob_score=True;, score=-50.565 total time=   1.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.362 total time=   1.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, oob_score=True;, score=-50.875 total time=   1.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500, oob_score=True;, score=-51.905 total time=   1.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-50.360 total time=   2.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.096 total time=   2.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-50.803 total time=   2.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, oob_score=True;, score=-51.770 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.365 total time=   2.5s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-51.795 total time=   2.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, oob_score=True;, score=-51.252 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, oob_score=True;, score=-50.858 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.683 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.803 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, oob_score=True;, score=-51.651 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, oob_score=True;, score=-50.851 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, oob_score=True;, score=-51.016 total time=   0.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.291 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.564 total time=   0.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.058 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, oob_score=True;, score=-50.836 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, oob_score=True;, score=-51.142 total time=   0.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.309 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.302 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-52.257 total time=   6.1s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-50.535 total time=   6.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-50.882 total time=   6.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.120 total time=   1.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500, oob_score=True;, score=-50.653 total time=   1.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500, oob_score=True;, score=-50.919 total time=   1.7s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.137 total time=   1.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.338 total time=   1.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-52.654 total time=   5.9s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-51.843 total time=   6.0s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-51.986 total time=   2.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-50.373 total time=   2.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-50.871 total time=   3.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.859 total time=   0.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-52.351 total time=   2.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, oob_score=True;, score=-51.192 total time=   0.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, oob_score=True;, score=-51.818 total time=   0.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, oob_score=True;, score=-53.248 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-51.957 total time=   3.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.606 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, oob_score=True;, score=-50.848 total time=   0.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.383 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, oob_score=True;, score=-51.171 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.661 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.579 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.444 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, oob_score=True;, score=-50.810 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, oob_score=True;, score=-51.180 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.616 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.283 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-50.532 total time=   5.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-52.174 total time=   6.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-50.909 total time=   5.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, oob_score=True;, score=-52.449 total time=   1.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, oob_score=True;, score=-50.691 total time=   1.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, oob_score=True;, score=-51.010 total time=   1.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, oob_score=True;, score=-52.497 total time=   1.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500, oob_score=True;, score=-52.060 total time=   1.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-52.708 total time=   6.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-51.954 total time=   6.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-52.128 total time=   2.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-50.520 total time=   2.9s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-51.001 total time=   2.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-52.388 total time=   2.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100, oob_score=True;, score=-53.412 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100, oob_score=True;, score=-51.477 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-51.952 total time=   3.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100, oob_score=True;, score=-51.564 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100, oob_score=True;, score=-53.367 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=100, oob_score=True;, score=-54.040 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200, oob_score=True;, score=-53.109 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200, oob_score=True;, score=-51.469 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200, oob_score=True;, score=-51.212 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200, oob_score=True;, score=-53.257 total time=   0.6s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=200, oob_score=True;, score=-53.039 total time=   0.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300, oob_score=True;, score=-53.359 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300, oob_score=True;, score=-51.201 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300, oob_score=True;, score=-51.591 total time=   0.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300, oob_score=True;, score=-53.137 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=300, oob_score=True;, score=-52.924 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-50.661 total time=   6.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-52.188 total time=   6.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-51.112 total time=   6.3s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500, oob_score=True;, score=-53.360 total time=   1.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500, oob_score=True;, score=-51.176 total time=   1.3s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500, oob_score=True;, score=-51.667 total time=   1.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500, oob_score=True;, score=-53.159 total time=   1.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=500, oob_score=True;, score=-52.885 total time=   1.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-52.667 total time=   6.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-51.993 total time=   6.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-53.000 total time=   2.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-51.157 total time=   2.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-51.578 total time=   2.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-53.115 total time=   2.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.443 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-52.529 total time=   2.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100, oob_score=True;, score=-51.189 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100, oob_score=True;, score=-50.716 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.804 total time=   0.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.826 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.280 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200, oob_score=True;, score=-50.670 total time=   1.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200, oob_score=True;, score=-50.824 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.635 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.529 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.487 total time=   1.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300, oob_score=True;, score=-50.808 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300, oob_score=True;, score=-50.958 total time=   0.8s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.549 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.331 total time=   0.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-53.016 total time=   6.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-51.268 total time=   6.5s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.368 total time=   1.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500, oob_score=True;, score=-50.530 total time=   1.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-51.651 total time=   5.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500, oob_score=True;, score=-50.917 total time=   1.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-53.311 total time=   5.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-52.569 total time=   6.0s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.449 total time=   1.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.040 total time=   1.5s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.138 total time=   2.9s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-50.883 total time=   2.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.439 total time=   2.8s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-50.394 total time=   2.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.443 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100, oob_score=True;, score=-51.189 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-51.964 total time=   3.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100, oob_score=True;, score=-50.716 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.826 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.804 total time=   0.5s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.280 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200, oob_score=True;, score=-50.670 total time=   0.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200, oob_score=True;, score=-50.824 total time=   0.6s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.635 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.529 total time=   1.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.487 total time=   1.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300, oob_score=True;, score=-50.808 total time=   1.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300, oob_score=True;, score=-50.958 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.549 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.331 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.368 total time=   1.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=500, oob_score=True;, score=-50.530 total time=   1.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-52.272 total time=   7.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-50.560 total time=   7.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-50.992 total time=   7.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=500, oob_score=True;, score=-50.917 total time=   1.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.449 total time=   1.6s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.040 total time=   1.6s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-52.697 total time=   7.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-51.969 total time=   7.5s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-52.138 total time=   2.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-50.394 total time=   2.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-50.883 total time=   3.0s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-52.439 total time=   3.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.805 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, oob_score=True;, score=-50.956 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, oob_score=True;, score=-51.729 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, oob_score=True;, score=-53.357 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.631 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.470 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, oob_score=True;, score=-50.720 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-51.964 total time=   4.2s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, oob_score=True;, score=-51.160 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.823 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.570 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.509 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, oob_score=True;, score=-50.713 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, oob_score=True;, score=-51.212 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.691 total time=   0.7s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.263 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-52.272 total time=   6.8s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-50.560 total time=   6.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-50.992 total time=   6.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=500, oob_score=True;, score=-52.499 total time=   1.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=500, oob_score=True;, score=-50.597 total time=   1.3s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=500, oob_score=True;, score=-51.070 total time=   1.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=500, oob_score=True;, score=-52.559 total time=   1.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=500, oob_score=True;, score=-52.025 total time=   1.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-52.697 total time=   7.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-51.969 total time=   7.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-52.186 total time=   3.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-50.493 total time=   3.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-51.045 total time=   3.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-52.429 total time=   3.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=100, oob_score=True;, score=-53.417 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-51.982 total time=   3.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=100, oob_score=True;, score=-51.487 total time=   0.3s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=100, oob_score=True;, score=-54.051 total time=   0.3s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=100, oob_score=True;, score=-51.595 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=100, oob_score=True;, score=-53.366 total time=   0.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=200, oob_score=True;, score=-51.249 total time=   0.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=200, oob_score=True;, score=-53.196 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=200, oob_score=True;, score=-51.488 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=200, oob_score=True;, score=-53.076 total time=   1.0s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=200, oob_score=True;, score=-53.260 total time=   1.1s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=300, oob_score=True;, score=-53.413 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=300, oob_score=True;, score=-51.282 total time=   0.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=300, oob_score=True;, score=-51.587 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=300, oob_score=True;, score=-53.165 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=300, oob_score=True;, score=-52.926 total time=   0.8s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-50.660 total time=   7.3s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-52.236 total time=   7.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=500, oob_score=True;, score=-53.376 total time=   1.8s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=500, oob_score=True;, score=-51.259 total time=   1.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-51.168 total time=   7.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=500, oob_score=True;, score=-51.656 total time=   1.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=500, oob_score=True;, score=-52.896 total time=   1.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=500, oob_score=True;, score=-53.155 total time=   1.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-51.985 total time=   7.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-52.685 total time=   7.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-53.049 total time=   2.8s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-51.225 total time=   2.8s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-51.569 total time=   2.8s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-53.119 total time=   2.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.889 total time=   0.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100, oob_score=True;, score=-50.868 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100, oob_score=True;, score=-51.989 total time=   0.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.970 total time=   0.5s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100, oob_score=True;, score=-52.785 total time=   0.3s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.608 total time=   0.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200, oob_score=True;, score=-50.716 total time=   0.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200, oob_score=True;, score=-51.413 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-52.545 total time=   4.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.629 total time=   1.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200, oob_score=True;, score=-52.476 total time=   0.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.633 total time=   1.2s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300, oob_score=True;, score=-50.806 total time=   1.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300, oob_score=True;, score=-51.420 total time=   0.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.502 total time=   0.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=300, oob_score=True;, score=-52.171 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-53.079 total time=   7.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.566 total time=   1.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-51.327 total time=   7.1s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500, oob_score=True;, score=-50.640 total time=   1.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-51.674 total time=   7.1s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500, oob_score=True;, score=-51.211 total time=   1.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-53.311 total time=   8.0s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.368 total time=   2.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=500, oob_score=True;, score=-52.005 total time=   2.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-52.578 total time=   8.3s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.301 total time=   3.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-50.577 total time=   3.7s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-51.172 total time=   4.1s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.332 total time=   4.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.889 total time=   0.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100, oob_score=True;, score=-50.868 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100, oob_score=True;, score=-51.989 total time=   0.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.970 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100, oob_score=True;, score=-52.785 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.608 total time=   0.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200, oob_score=True;, score=-50.716 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-52.020 total time=   5.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200, oob_score=True;, score=-51.413 total time=   1.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.629 total time=   1.1s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=200, oob_score=True;, score=-52.476 total time=   1.0s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.633 total time=   1.0s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300, oob_score=True;, score=-50.806 total time=   1.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300, oob_score=True;, score=-51.420 total time=   1.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.502 total time=   0.9s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300, oob_score=True;, score=-52.171 total time=   0.9s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-51.271 total time=   8.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-50.763 total time=   8.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.566 total time=   1.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-52.329 total time=   9.0s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500, oob_score=True;, score=-50.640 total time=   1.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500, oob_score=True;, score=-51.211 total time=   1.7s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.005 total time=   1.8s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=500, oob_score=True;, score=-52.368 total time=   2.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-51.979 total time=   9.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-52.618 total time=   9.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-52.301 total time=   3.5s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-50.577 total time=   3.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-51.172 total time=   3.7s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.889 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-52.332 total time=   4.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, oob_score=True;, score=-50.868 total time=   0.4s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, oob_score=True;, score=-51.989 total time=   0.4s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.970 total time=   0.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, oob_score=True;, score=-52.785 total time=   0.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.608 total time=   0.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, oob_score=True;, score=-50.716 total time=   1.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-52.020 total time=   5.6s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, oob_score=True;, score=-51.413 total time=   1.5s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.629 total time=   1.0s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, oob_score=True;, score=-52.476 total time=   0.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300, oob_score=True;, score=-52.633 total time=   1.3s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300, oob_score=True;, score=-50.806 total time=   1.4s
# ...
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-35.372 total time=   5.2s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-36.183 total time=   5.2s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100, oob_score=True;, score=-35.737 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100, oob_score=True;, score=-35.569 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100, oob_score=True;, score=-34.988 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100, oob_score=True;, score=-36.583 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100, oob_score=True;, score=-35.257 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000, oob_score=True;, score=-34.845 total time=   6.2s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200, oob_score=True;, score=-35.567 total time=   1.0s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200, oob_score=True;, score=-35.337 total time=   1.2s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200, oob_score=True;, score=-34.768 total time=   1.4s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200, oob_score=True;, score=-36.299 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=200, oob_score=True;, score=-35.106 total time=   1.2s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=300, oob_score=True;, score=-35.527 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=300, oob_score=True;, score=-35.285 total time=   1.3s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=300, oob_score=True;, score=-34.668 total time=   1.2s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=300, oob_score=True;, score=-36.289 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=300, oob_score=True;, score=-34.881 total time=   1.5s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500, oob_score=True;, score=-35.486 total time=   2.3s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-35.428 total time=  11.3s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-35.301 total time=  11.2s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-34.433 total time=  11.2s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500, oob_score=True;, score=-35.390 total time=   1.9s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500, oob_score=True;, score=-34.528 total time=   2.2s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500, oob_score=True;, score=-34.977 total time=   2.0s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500, oob_score=True;, score=-36.200 total time=   2.1s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-36.243 total time=  10.4s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=2000, oob_score=True;, score=-34.871 total time=  10.6s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-35.462 total time=   4.0s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-35.372 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-34.448 total time=   4.5s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100, oob_score=True;, score=-35.737 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100, oob_score=True;, score=-35.569 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-36.183 total time=   4.9s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100, oob_score=True;, score=-34.988 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100, oob_score=True;, score=-36.583 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=100, oob_score=True;, score=-35.257 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000, oob_score=True;, score=-34.845 total time=   5.6s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200, oob_score=True;, score=-35.567 total time=   1.5s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200, oob_score=True;, score=-35.337 total time=   1.5s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200, oob_score=True;, score=-34.768 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200, oob_score=True;, score=-36.299 total time=   1.4s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200, oob_score=True;, score=-35.106 total time=   1.2s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300, oob_score=True;, score=-35.527 total time=   1.4s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300, oob_score=True;, score=-35.285 total time=   1.2s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300, oob_score=True;, score=-34.668 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300, oob_score=True;, score=-36.289 total time=   1.2s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300, oob_score=True;, score=-34.881 total time=   1.2s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-35.428 total time=  10.6s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-35.301 total time=  10.1s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500, oob_score=True;, score=-35.486 total time=   2.0s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-34.433 total time=  10.0s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500, oob_score=True;, score=-35.390 total time=   1.6s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500, oob_score=True;, score=-34.528 total time=   1.6s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-34.871 total time=  10.2s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=2000, oob_score=True;, score=-36.243 total time=  10.5s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500, oob_score=True;, score=-36.200 total time=   2.2s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500, oob_score=True;, score=-34.977 total time=   2.1s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-35.372 total time=   4.4s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-35.462 total time=   4.7s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-34.448 total time=   4.8s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-36.183 total time=   5.0s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100, oob_score=True;, score=-35.737 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100, oob_score=True;, score=-35.569 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100, oob_score=True;, score=-34.988 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100, oob_score=True;, score=-36.583 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=100, oob_score=True;, score=-35.257 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000, oob_score=True;, score=-34.845 total time=   5.4s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200, oob_score=True;, score=-35.567 total time=   1.3s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200, oob_score=True;, score=-35.337 total time=   1.4s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200, oob_score=True;, score=-34.768 total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200, oob_score=True;, score=-36.299 total time=   1.3s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=200, oob_score=True;, score=-35.106 total time=   1.4s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300, oob_score=True;, score=-35.527 total time=   1.3s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300, oob_score=True;, score=-35.285 total time=   1.2s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300, oob_score=True;, score=-34.668 total time=   1.3s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300, oob_score=True;, score=-36.289 total time=   1.2s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=300, oob_score=True;, score=-34.881 total time=   1.2s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-35.428 total time=  10.8s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-35.301 total time=  10.7s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-34.433 total time=  10.6s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500, oob_score=True;, score=-35.486 total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500, oob_score=True;, score=-35.390 total time=   1.8s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500, oob_score=True;, score=-34.528 total time=   1.8s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500, oob_score=True;, score=-36.200 total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=500, oob_score=True;, score=-34.977 total time=   2.1s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-36.243 total time=  10.2s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=2000, oob_score=True;, score=-34.871 total time=  10.4s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-35.462 total time=   4.1s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-35.372 total time=   4.3s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-34.448 total time=   4.8s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-36.183 total time=   4.7s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=1000, oob_score=True;, score=-34.845 total time=   5.3s
# [CV 1/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-35.428 total time=   7.8s
# [CV 2/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-35.301 total time=   7.8s
# [CV 3/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-34.433 total time=   7.5s
# [CV 4/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-36.243 total time=   6.8s
# [CV 5/5] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=2000, oob_score=True;, score=-34.871 total time=   6.5s
# GridSearchCV finished in 2102.46 seconds.
#
# Best parameters found by GridSearchCV:
# {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 2000, 'oob_score': True}
#
# Best cross-validation score (Negative MAE): -25.1823
# Corresponds to MAE: 25.1823
#
# Best model training complete.
# Best Model OOB score: 0.9477

# %% [markdown]
# ## Evaluate

# %%
def evaluate_model(model, X_test, Y_test):
    """Evaluates the model using MAE and MSE."""
    Y_pred = model.predict(X_test)

    mae = mean_absolute_error(Y_test, Y_pred)
    mse = mean_squared_error(Y_test, Y_pred)
    rmse = np.sqrt(mse) # Root Mean Squared Error

    print("\n--- Model Evaluation ---")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"Mean Squared Error (MSE):  {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

    # Optional: Print metrics per output feature
    print("\nMAE per output feature:")
    output_features = [
        'dist_red_final', 'angle_red_final', 'dist_green_final',
        'angle_green_final', 'dist_blue_final', 'angle_blue_final'
    ]
    for i, name in enumerate(output_features):
         mae_feature = mean_absolute_error(Y_test[:, i], Y_pred[:, i])
         print(f"  {name}: {mae_feature:.4f}")

    return mae, mse

# %%
# 6. Evaluate the Best Model found by GridSearch (using scaled test data)
if world_model is not None:
    evaluate_model(world_model, X_test_scaled, Y_test)
# Out:
# --- Model Evaluation ---
# Mean Absolute Error (MAE): 24.3979
# Mean Squared Error (MSE):  1798.4146
# Root Mean Squared Error (RMSE): 42.4077
#
# MAE per output feature:
#   dist_red_final: 40.7431
#   angle_red_final: 8.4946
#   dist_green_final: 36.7146
#   angle_green_final: 18.2790
#   dist_blue_final: 38.3186
#   angle_blue_final: 3.8372

# %% [markdown]
# ## Save model

# %%
def save_model_and_scaler(model, scaler, model_filename="world_model_v3.joblib", scaler_filename="scaler_v3.joblib"):
    """Saves the trained model and scaler to disk."""
    try:
        # Ensure the directory exists
        model_dir = "../src/models"
        os.makedirs(model_dir, exist_ok=True)

        model_path = os.path.join(model_dir, model_filename)
        scaler_path = os.path.join(model_dir, scaler_filename)

        joblib.dump(model, model_path)
        joblib.dump(scaler, scaler_path)
        print(f"Model saved to {model_path}")
        print(f"Scaler saved to {scaler_path}")
    except Exception as e:
        print(f"Error saving model/scaler: {e}")

# %%
# 7. Save Model and Scaler
save_model_and_scaler(world_model, scaler)
# Out:
# Model saved to ../src/models/world_model_v3.joblib
# Scaler saved to ../src/models/scaler_v3.joblib

# %%
# Example prediction (how you'd use it later)
print("\n--- Example Prediction ---")

# Take the first sample from the original test set
sample_X = X_test[0].reshape(1, -1)
sample_Y_actual = Y_test[0]

# Scale the sample using the *saved* scaler
sample_X_scaled = scaler.transform(sample_X)

# Predict using the trained model
sample_Y_pred = world_model.predict(sample_X_scaled)

print(f"Input State + Action: {sample_X[0]}")
print(f"Actual Final State:   {sample_Y_actual}")
print(f"Predicted Final State:{sample_Y_pred[0]}")
# Out:
# --- Example Prediction ---
# Input State + Action: [ 4.10674455e+02  1.22678632e+02  1.39104272e+03 -1.74541181e+02
#   8.04670468e+02  5.43256407e+01  1.00000000e+00 -6.00000000e+00]
# Actual Final State:   [ 419.68603568  120.04972943 1377.94257775 -175.22419136  825.72434115
#    54.38562828]
# Predicted Final State:[ 418.00912156  123.23844485 1385.85273925 -173.32613874  813.60056139
#    55.5324251 ]
